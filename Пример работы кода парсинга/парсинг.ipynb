# %% [markdown]
# # Парсинг данных

# %% [markdown]
# Наша команда не хотела брать готовый парсер, поскольку мы опасались не понимать работу кода. По этой причине мы решили парсить самостоятельно.
# Изначально для парсинга был выбран сайт ЦИАН, но, тщательно изучив объявления на нем, наша команда выяснила, что у этого сайта достаточно неупорядоченный интерфейс. Спарсив его, мы бы столкнулись с проблемой огромного количества пропуска данных, что несомненно сказалось бы на качестве работы модели. Но команда нашла альтернативный сайт по продаже недвижимости - Авито. Он обладает более понятной и упорядоченной структурой, что помогает преодолеть трудность в виде пропусков. По этой причине мы сменили источник. Более того, у Авито более понятная html-структура страницы.

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\programdata\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: trio~=0.17 in c:\programdata\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: certifi>=2021.10.8 in c:\programdata\anaconda3\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: trio-websocket~=0.9 in c:\programdata\anaconda3\lib\site-packages (from selenium) (0.10.3)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\programdata\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
url = "https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ"
driver = webdriver.Chrome()

# %%
from selenium.webdriver.common.by import By
driver.get(url)

# %%
all_links = []
num_pages = 25
for i in range(1, num_pages):
    flats_one_page = driver.find_elements(By.TAG_NAME,'a')
    for flat in flats_one_page:
        all_links.append(flat.get_attribute("href"))
        print(flat.get_attribute("href"))    
    print(i)
    driver.find_element("xpath", "//*[@id='app']/div/div[3]/div/div[2]/div[3]/div[3]/div[5]/nav/ul/li[9]/a").click()
# Out:
# https://www.avito.ru/avito-care?from=mp_banner_header
# https://www.avito.ru/business
# https://career.avito.com/?utm_source=avito.ru&utm_medium=referral&utm_campaign=test_placement_to_career&utm_content=top_vacancy
# https://support.avito.ru/
# https://www.avito.ru/catalog/auto
# https://www.avito.ru/avito-care?from=mp_header
# https://www.avito.ru/favorites
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ#login?next=/order/cart
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ#login?authsrc=h
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ#login?next=%2Fadditem&authsrc=ca
# https://www.avito.ru/
# https://www.avito.ru/moskva/transport?cd=1
# https://www.avito.ru/moskva/nedvizhimost?cd=1
# https://www.avito.ru/moskva/rabota?cd=1
# https://www.avito.ru/moskva/predlozheniya_uslug?cd=1
# https://www.avito.ru/moskva/lichnye_veschi?cd=1
# https://www.avito.ru/moskva/dlya_doma_i_dachi?cd=1
# https://www.avito.ru/moskva/zapchasti_i_aksessuary?cd=1
# https://www.avito.ru/moskva/bytovaya_elektronika?cd=1
# https://www.avito.ru/moskva/hobbi_i_otdyh?cd=1
# https://www.avito.ru/moskva/zhivotnye?cd=1
# https://www.avito.ru/moskva/dlya_biznesa?cd=1
# https://www.avito.ru/moskva
# https://www.avito.ru/moskva/nedvizhimost
# https://www.avito.ru/moskva/kvartiry
# https://www.avito.ru/moskva/kvartiry/prodam-ASgBAgICAUSSA8YQ
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg
# https://www.avito.ru/moskva/nedvizhimost?cd=1
# https://www.avito.ru/moskva/kvartiry/prodam-ASgBAgICAUSSA8YQ?cd=1
# https://www.avito.ru/moskva/kvartiry/prodam-ASgBAgICAUSSA8YQ?cd=1
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?cd=1
# https://www.avito.ru/moskva/kvartiry/prodam/novostroyka-ASgBAQICAUSSA8YQAUDmBxSOUg?cd=1
# https://www.avito.ru/moskva/kvartiry/catalog/novostroyki-ASgBAQICAkSSA8YQ8sUO8JOaAgFA5gcUjlI
profile?src=search_seller_info
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ#login?next=%3Fwritein%3D2675968201&authsrc=w
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_516m_1216et._3124028898
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_516m_1216et._3124028898
# https://www.avito.ru/user/1c9ab284c784a1c42eb7672e8cc99252/profile?src=search_seller_info
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ#login?next=%3Fwritein%3D3124028898&authsrc=w
# https://www.avito.ru/moskva/kvartiry/3-k._kvartira_110m_44et._3077935715
# https://www.avito.ru/moskva/kvartiry/3-k._kvartira_110m_44et._3077935715
# https://www.avito.ru/ndv_ru?page_from=from_items_list_icon&iid=3077935715
# https://www.avito.ru/user/1ff6d56d24e4e3fefbb83630b81592a6/profile?src=search_seller_info
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ#login?next=%3Fwritein%3D3077935715&authsrc=w
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_45m_79et._2862492141
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_45m_79et._2862492141
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?expanded=4&f=ASgBAQICAkSSA8YQzLwNhvzQdAJA5gcUjFLKCKSKWZqsAZisAZasAZSsAYhZhlmEWYJZgFk
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_361m_225et._2578095050
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_361m_225et._2578095050
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ#login?next=%3Fwritein%3D2578095050&authsrc=w
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ&p=2
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ&p=3
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ&p=4
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ&p=5
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ&p=6
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ&p=7
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ&p=8
# https://www.avito.ru/moskva/kvartiry/prodam/vtorichka-ASgBAQICAUSSA8YQAUDmBxSMUg?f=ASgBAQICAUSSA8YQAkDmBxSMUsoIpIpZmqwBmKwBlqwBlKwBiFmGWYRZglmAWQ&p=9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       5 for flat in flats_one_page:
#       6     all_links.append(flat.get_attribute("href"))
# ----> 7     print(flat.get_attribute("href"))
#       8 print(i)
#       9 driver.find_element("xpath", "//*[@id='app']/div/div[3]/div/div[2]/div[3]/div[3]/div[5]/nav/ul/li[9]/a").click()
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:178, in WebElement.get_attribute(self, name)
#     176 if getAttribute_js is None:
#     177     _load_js()
# --> 178 attribute_value = self.parent.execute_script(
#     179     f"/* getAttribute */return ({getAttribute_js}).apply(null, arguments);", self, name
#     180 )
#     181 return attribute_value
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:406, in WebDriver.execute_script(self, script, *args)
#     403 converted_args = list(args)
#     404 command = Command.W3C_EXECUTE_SCRIPT
# --> 406 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     341     elif "sessionId" not in params:
#     342         params["sessionId"] = self.session_id
# --> 344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
#     346     self.error_handler.check_response(response)
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File C:\ProgramData\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File C:\ProgramData\anaconda3\lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File C:\ProgramData\anaconda3\lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File C:\ProgramData\anaconda3\lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File C:\ProgramData\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File C:\ProgramData\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File C:\ProgramData\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\ProgramData\anaconda3\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File C:\ProgramData\anaconda3\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\ProgramData\anaconda3\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\ProgramData\anaconda3\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# Сначала мы собираем абсолютно все ссылки с каждой страницы

# %%
PATTERN_1 = 'https://www.avito.ru/moskva/kvartiry/'
PATTERN_2 = "-k._kvartira_"
with open("flat_links1.txt", "w" ) as file:
    for url in all_links:
        if url != None:
            if url.__contains__(PATTERN_1) and  url.__contains__(PATTERN_2):
                print(url, file = file)

# %% [markdown]
# Затем по PATTERN_1, PATTERN_2 ищем именно объявления о продаже квартир вторичного жилья и сохраняем в "flat_links1.txt". Однако при просмотре текстового файла выяснили, что одна и та же ссылка записывается 2 раза. Решаем эту проблему ниже.

# %%
with open("flat_links1.txt", "r" ) as file:
    with open("flat_links2.txt", "w" ) as infile:
        i = 0
        for line in file:
            if i % 2 == 0:
                print(line, file = infile, end = "")
            i += 1

# %% [markdown]
# Данный файл создается по следующей причине: при каждой новой имитации входа человека на сайт Авито, он обновляет объявления на всех страницах. Так как наша команда работает на нескольких компьютерах одновременно, с целью оптимизации нашей работы мы создали текстовый документ, в который записали все необходимые нам объявления на каждой странице. Тем самым мы решаем проблему записи одинаковых данных на разных компьютерах.
#
# Получили текстовый файл "flat_links2.txt", где на каждой строчке находятся ссылки на необходимые нам объявления.
# Поскольку при запуске кода на одном компьютере данные парсились очень долго, решили преобразовать код, чтобы иметь возможность запустить код в ячейке ниже на разных компьютерах (21 штука) одновременно, "делегируя" обязанности между ними. А именно принцип был следующий: первый компьютер парсит данные с 1 строки по 50 и сохраняет полученные данные в our_csv1.csv, второй - с 50 по 100 и сохраняет полученные данные в our_csv2.csv и т.д. Это позволяет ускорить код.

# %%
with open("flat_links2.txt", "r") as file:
    with open("our_csv12 (1).csv", "w", encoding='UTF-8') as infile:
        print("Metro; Number of Rooms; Square; Current Floor; Total Floors; Auction; Price; Requisites Checked", end = "\n", file = infile)
        lines = file.readlines()
        for i in range(550, 600):
            link = lines[i]
            print(link)
            driver.get(link)
            try:
                metro = driver.find_element("xpath", "//*[@id='app']/div/div[2]/div[1]/div[2]/div[4]/div[1]/div[2]/div[2]/div/div[2]/div[1]/div/div/span/span[1]/span[2]").text
                print(metro, end = ";", file = infile) 
                print(metro) 
                string = driver.find_element(By.CLASS_NAME, "title-info-title-text").text
                
                if string.find("Аукцион") == -1:
                    lst = string.split()     
                    number_rooms = lst[0].split("-")[0]
                    print(number_rooms, end = ";", file = infile)  
                    square = lst[2]   
                    print(square, end = ";", file = infile)  
                    current_floor = lst[4].split("/")[0]
                    print(current_floor, end = ";", file = infile)   
                    total_floors = lst[4].split("/")[1]   
                    print(total_floors, end = ";", file = infile)
                    print('Нет аукциона', end = ";", file = infile)
                else:
                    lst = string.split()     
                    number_rooms = lst[1].split("-")[0]
                    print(number_rooms, end = ";", file = infile)  
                    square = lst[3]   
                    print(square, end = ";", file = infile) 
                    current_floor = lst[5].split("/")[0]
                    print(current_floor, end = ";", file = infile)   
                    total_floors = lst[5].split("/")[1]   
                    print(total_floors, end = ";", file = infile)
                    print('Аукцион', end = ";", file = infile)
                    
                price = driver.find_element(By.CLASS_NAME, "styles-module-size_xxxl-A2qfi").text
                print(price, end = ";", file = infile)  
                try:   
                    requisites_checked = driver.find_element(By.CLASS_NAME, "SnippetBadge-title-oSImJ").text
                    print(requisites_checked, end = "\n", file = infile)
                except:     
                    requisites_checked = "Реквизиты не проверены"
                    print(requisites_checked, end = "\n", file = infile)
            except:   
                try:
                    metro = driver.find_element("xpath", "//*[@id='app']/div/div[2]/div[1]/div[2]/div[3]/div[1]/div[2]/div[2]/div/div[2]/div[1]/div/div/span/span[1]/span[2]").text                  
                    print(metro, end = ";", file = infile) 
                    string = driver.find_element(By.CLASS_NAME, "title-info-title-text").text
                    
                    if string.find("Аукцион") == -1:
                        lst = string.split()     
                        number_rooms = lst[0].split("-")[0]
                        print(number_rooms, end = ";", file = infile)  
                        square = lst[2]   
                        print(square, end = ";", file = infile)  
                        current_floor = lst[4].split("/")[0]
                        print(current_floor, end = ";", file = infile)   
                        total_floors = lst[4].split("/")[1]   
                        print(total_floors, end = ";", file = infile)
                        print('Нет аукциона', end = ";", file = infile)
                    else:
                        lst = string.split()     
                        number_rooms = lst[1].split("-")[0]
                        print(number_rooms, end = ";", file = infile)  
                        square = lst[3]   
                        print(square, end = ";", file = infile)  
                        current_floor = lst[5].split("/")[0]
                        print(current_floor, end = ";", file = infile)
                        total_floors = lst[5].split("/")[1]   
                        print(total_floors, end = ";", file = infile)
                        print('Аукцион', end = ";", file = infile)
                    price = driver.find_element(By.CLASS_NAME, "styles-module-size_xxxl-A2qfi").text
                    print(price, end = ";", file = infile)
                    try:   
                        requisites_checked = driver.find_element(By.CLASS_NAME, "SnippetBadge-title-oSImJ").text
                        print(requisites_checked, end = "\n", file = infile)
                    except:     
                        requisites_checked = "Реквизиты не проверены"
                        print(requisites_checked, end = "\n", file = infile)
                except: 
                    continue
# Out:
# https://www.avito.ru/moskva/kvartiry/3-k._kvartira_136m_67et._2591577979
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_39m_1616et._2871106679
#
# https://www.avito.ru/moskva/kvartiry/3-k._kvartira_52m_79et._2895929523
#
# https://www.avito.ru/moskva/kvartiry/auktsion_1-k._kvartira_35m_912et._2593494581
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_41m_15et._2937519163
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_353m_618et._3077746104
#
# https://www.avito.ru/moskva/kvartiry/3-k._kvartira_75m_1617et._2991648823
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_447m_68et._2649456009
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_321m_19et._2326512812
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_413m_45et._2406665528
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_45m_89et._2830069608
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_70m_1232et._2651719360
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_38m_1717et._2912943311
#
# https://www.avito.ru/moskva/kvartiry/3-k._kvartira_776m_2123et._2443817845
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_455m_19et._2845762880
#
# https://www.avito.ru/moskva/kvartiry/3-k._kvartira_643m_112et._2990329198
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_503m_89et._2874946278
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_691m_710et._3034624066
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_57m_1829et._2836071927
#
# https://www.avito.ru/moskva/kvartiry/3-k._kvartira_71m_1625et._2853728022
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_41m_321et._2875257027
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_722m_822et._2965059858
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_575m_1116et._2867925440
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_32m_59et._2971455384
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_375m_99et._2854229872
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_476m_46et._2749380964
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_19m_48et._2622732452
#
# https://www.avito.ru/moskva/kvartiry/4-k._kvartira_139m_39et._2827961712
#
# https://www.avito.ru/moskva/kvartiry/3-k._kvartira_509m_49et._2336517071
#
# https://www.avito.ru/moskva/kvartiry/3-k._kvartira_79m_1314et._2858872604
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_628m_625et._2903001567
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_44m_68et._2628929707
#
# https://www.avito.ru/moskva/kvartiry/3-k._kvartira_85m_1318et._2673672428
#
# https://www.avito.ru/moskva/kvartiry/4-k._kvartira_2523m_1157et._3060372568
#
# https://www.avito.ru/moskva/kvartiry/4-k._kvartira_1426m_36et._2753238262
#
# https://www.avito.ru/moskva/kvartiry/4-k._kvartira_100m_835et._2530380538
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_349m_35et._2623108893
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_378m_1717et._3201859471
#
# https://www.avito.ru/moskva/kvartiry/3-k._kvartira_761m_39et._2890726093
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_36m_117et._3101670922
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_319m_99et._2784039745
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_32m_15et._2618275764
#
# https://www.avito.ru/moskva/kvartiry/4-k._kvartira_1406m_88et._2758867301
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_36m_3747et._2671747430
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_506m_1416et._2828471256
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_508m_417et._2911107125
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_45m_19et._2391760725
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_305m_15et._2487149133
#
# https://www.avito.ru/moskva/kvartiry/2-k._kvartira_381m_912et._2878468127
#
# https://www.avito.ru/moskva/kvartiry/1-k._kvartira_414m_917et._2903444041

# %% [markdown]
# В данном коде мы открываем текстовый файл "flat_links2.txt" с ссылками на объявления, проходимся циклом for по ссылкам и сразу записываем полученные признаки в файл csv.
#
# Нами были выбраны признаки "Metro" - станция метро, 'Number of Rooms' - количество комнат, "Square" - общая площадь; "Current Floor" - этаж, на котором находится квартира; "Total Floors" - общее количество этажей в доме; "Auction" - наличие аукциона; "Requisites Checked" - наличие проверенных реквизитов и "Price" - цена, наша целевая переменная.
#
# Мы разграничили код по переменной "Auction", поскольку когда квартира находилась на аукционе, то менялся паттерн, по которому происходило сплитование строки (if-else).
#
# Также было 2 возможных xpath для метро в зависимости от типа объявления (try-except). А также мы обходили случай, когда станция метро не указана в объявлении путем использования вложенного try-except. Такие объявления не рассматривались, так как путем анализа нескольких из них, выяснили, что они находятся не в Москве, а в Подмосковье, несмотря на установленные фильтры на сайте.
